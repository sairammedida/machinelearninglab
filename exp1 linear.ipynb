# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
#step 2 load the dataset
df=pd.read_csv(r"D:\insurancecharges.csv")

# %%
#step 3 extract dependent and indcependent varible 
x=df[['bmi']]
print("independent variable values are :")
print(x)
y=df['charges']
print("dependent variables values are:")
print(y)
# Out:
# independent variable values are :
#        bmi
# 0   27.900
# 1   33.770
# 2   33.000
# 3   22.705
# 4   28.880
# 5   25.740
# 6   33.440
# 7   27.740
# 8   29.830
# 9   25.840
# 10  26.220
# 11  26.290
# 12  34.400
# 13  39.820
# 14  42.130
# 15  24.600
# 16  30.780
# 17  23.845
# 18  40.300
# dependent variables values are:
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 5      3756.62160
# 6      8240.58960
# 7      7281.50560
# 8      6406.41070
# 9     28923.13692
# 10     2721.32080
# 11    27808.72510
# 12     1826.84300
# 13    11090.71780
# 14    39611.75770
# 15     1837.23700
# 16    10797.33620
# 17     2395.17155
# 18    10602.38500
# Name: charges, dtype: float64

# %%
#step 4 split the data into training and- testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5)

# %%
#step 5fiting simpple linear regression to the trainning set 
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#step 6 predicting the test set result
y_pred=model.predict(x_test)

# %%
#evaluate the model
print(f'Mean Squared Error: {mean_squared_error(y_test,y_pred)}')
print(f'R-squared:{r2_score(y_test,y_pred)}')
# Out:
# Mean Squared Error: 126259996.47681518
# R-squared:-0.7950218558423661

# %%
plt.scatter(x_train,y_train,color='blue',label='training data')
plt.plot(x_train,model.predict(x_train),color='red',label='regression line')
plt.xlabel=('bmi reports')
plt.ylabel=('insurance charges')
plt.title("insurance charges")
plt.legend()
plt.show()

# %%
plt.scatter(x_test,y_test,color='green',label='Testdata')
plt.plot(x_train,model.predict(x_train),color='red',label='regression line')
plt.xlabel=("bmi reports")
plt.ylabel=('insurance charges')
plt.title("insurances charges")
plt.legend()
plt.show()
